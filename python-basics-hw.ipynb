# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики, которые вечно стоят над душой и нудят'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде, в которую все предпочитают верить)'

# %%
len(long_phrase) > len(short_phrase)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
size_kb = int(input('Объем файла в байтах: '))
size_mb = size_kb / 1000
print('Объем файла равен', size_mb, 'Mb')
# Out:
# Объем файла в байтах: 456876
# Объем файла равен 456.876 Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
# Комментарий: кажется, что можно все это написать короче, но не могу разобраться с тем как работает объединение скобками, 
# например, можно ли с их помощью упростить условие типа if month == 'апрель' or month == 'Апрель': (варианты, 
# которые я пробовал, не сработали)
# решения, как избежать двух вариантов регистра и прописать, чтобы условие не было к нему чувствительно, 
# я с первого раза не нашел в сети
# и можно ли в одно это условие включить и вариант написания месяца буквами, и запись месяца числом
month = input('Введите месяц вашего рождения: ')
date = int(input('Введите дату вашего рождения: '))
if month == 'апрель' or month == 'Апрель':
    if date <= 20:
        print('Ваш знак зодиака: Овен')
    elif 20 < date <= 30:
        print('Ваш знак зодиака: Телец')
    else:
        print('Некорректная дата рождения')
elif month == 'май' or month == 'Май':
    if date <= 20:
        print('Ваш знак зодиака: Телец')
    elif 20 < date <= 31:
        print('Ваш знак зодиака: Близнецы')
    else:
        print('Некорректная дата рождения')
elif month == 'июнь' or month == 'Июнь':
    if date <= 21:
        print('Ваш знак зодиака: Близнецы')
    elif 21 < date <= 30:
        print('Ваш знак зодиака: Рак')
    else:
        print('Некорректная дата рождения')
elif month == 'июль' or month == 'Июль':
    if date <= 21:
        print('Ваш знак зодиака: Рак')
    elif 22 < date <= 31:
        print('Ваш знак зодиака: Лев')
    else:
        print('Некорректная дата рождения')
elif month == 'август' or month == 'Август':
    if date <= 23:
        print('Ваш знак зодиака: Лев')
    elif 23 < date <= 31:
        print('Ваш знак зодиака: Дева')
    else:
        print('Некорректная дата рождения')
elif month == 'сентябрь' or month == 'Сентябрь':
    if date <= 23:
        print('Ваш знак зодиака: Дева')
    elif 23 < date <= 30:
        print('Ваш знак зодиака: Весы')
    else:
        print('Некорректная дата рождения')
elif month == 'октябрь' or month == 'Октябрь':
    if date <= 23:
        print('Ваш знак зодиака: Весы')
    elif 23 < date <= 31:
        print('Ваш знак зодиака: Скорпион')
    else:
        print('Некорректная дата рождения')
elif month == 'ноябрь' or month == 'Ноябрь':
    if date <= 22:
        print('Ваш знак зодиака: Скорпион')
    elif 22 < date <= 30:
        print('Ваш знак зодиака: Стрелец')
    else:
        print('Некорректная дата рождения')
elif month == 'декабрь' or month == 'Декабрь':
    if date <= 21:
        print('Ваш знак зодиака: Стрелец')
    elif 21 < date <= 31:
        print('Ваш знак зодиака: Козерог')
    else:
        print('Некорректная дата рождения')
elif month == 'январь' or month == 'Январь':
    if date <= 20:
        print('Ваш знак зодиака: Козерог')
    elif 20 < date <= 31:
        print('Ваш знак зодиака: Водолей')
    else:
        print('Некорректная дата рождения')
elif month == 'февраль' or month == 'Февраль':
    if date <= 20:
        print('Ваш знак зодиака: Водолей')
    elif 20 < date <= 29:
        print('Ваш знак зодиака: Рыбы')
    else:
        print('Некорректная дата рождения')
elif month == 'март' or month == 'Март':
    if date <= 20:
        print('Ваш знак зодиака: Рыбы')
    elif 20 < date <= 31:
        print('Ваш знак зодиака: Овен')
    else:
        print('Некорректная дата рождения')
else:
    print('Некорректный месяц рождения')
# Out:
# Введите месяц вашего рождения: Декабрь
# Введите дату вашего рождения: 07
# Ваш знак зодиака: Стрелец

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
salary = int(input('Введите ваш ежемесячный доход: '))
percent_debt = int(input('Какой процент вашего дохода уходит на оплату ипотеки: '))
percent_life = int(input('Какой процент вашего дохода уходит на жизнь: '))
gift = int(input('Сколько раз в год вы получаете премию: '))
debt_year = salary / 100 * percent_debt * 12
savings_year = (salary - salary / 100 * percent_life) * 12 + (salary * gift) / 2 - debt_year

print('Потрачено на ипотеку за год:', debt_year, 'рублей;', 'Накоплено на пенcионном счету:', savings_year, 'рублей.')
# Out:
# Введите ваш ежемесячный доход: 200000
# Какой процент вашего дохода уходит на оплату ипотеки: 40
# Какой процент вашего дохода уходит на жизнь: 45
# Сколько раз в год вы получаете премию: 1
# Потрачено на ипотеку за год: 960000.0 рублей; Накоплено на пенcионном счету: 460000.0 рублей.
